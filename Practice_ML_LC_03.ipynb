# %%
# import pandas as pd
import seaborn as sb

# %%
df = sb.load_dataset('titanic')
df
# df.head(2)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['embark_town'] = le.fit_transform(df['embark_town'])

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN            2    no  False
# 1    woman       False    C            0   yes  False
# 2    woman       False  NaN            2   yes   True
# 3    woman       False    C            2   yes  False
# 4      man        True  NaN            2    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN            2    no   True
# 887  woman       False    B            2   yes   True
# 888  woman       False  NaN            2    no  False
# 889    man        True    C            0   yes   True
# 890    man        True  NaN            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['sex'] = le.fit_transform(df['sex'])

# %%
df
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    1  22.0      1      0   7.2500        S   Third
# 1           1       1    0  38.0      1      0  71.2833        C   First
# 2           1       3    0  26.0      0      0   7.9250        S   Third
# 3           1       1    0  35.0      1      0  53.1000        S   First
# 4           0       3    1  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    1  27.0      0      0  13.0000        S  Second
# 887         1       1    0  19.0      0      0  30.0000        S   First
# 888         0       3    0   NaN      1      2  23.4500        S   Third
# 889         1       1    1  26.0      0      0  30.0000        C   First
# 890         0       3    1  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN            2    no  False
# 1    woman       False    C            0   yes  False
# 2    woman       False  NaN            2   yes   True
# 3    woman       False    C            2   yes  False
# 4      man        True  NaN            2    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN            2    no   True
# 887  woman       False    B            2   yes   True
# 888  woman       False  NaN            2    no  False
# 889    man        True    C            0   yes   True
# 890    man        True  NaN            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['fare'] = le.fit_transform(df['fare'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare embarked   class    who  \
# 0           0       3    1   28      1      0    18        S   Third    man
# 1           1       1    0   51      1      0   207        C   First  woman
# 2           1       3    0   34      0      0    41        S   Third  woman
# 3           1       1    0   47      1      0   189        S   First  woman
# 4           0       3    1   47      0      0    43        S   Third    man
# ..        ...     ...  ...  ...    ...    ...   ...      ...     ...    ...
# 886         0       2    1   35      0      0    85        S  Second    man
# 887         1       1    0   24      0      0   153        S   First  woman
# 888         0       3    0   88      1      2   131        S   Third  woman
# 889         1       1    1   34      0      0   153        C   First    man
# 890         0       3    1   42      0      0    30        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN            2    no  False
# 1         False    C            0   yes  False
# 2         False  NaN            2   yes   True
# 3         False    C            2   yes  False
# 4          True  NaN            2    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN            2    no   True
# 887       False    B            2   yes   True
# 888       False  NaN            2    no  False
# 889        True    C            0   yes   True
# 890        True  NaN            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['embarked'] = le.fit_transform(df['embarked'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked   class    who  \
# 0           0       3    1   28      1      0    18         2   Third    man
# 1           1       1    0   51      1      0   207         0   First  woman
# 2           1       3    0   34      0      0    41         2   Third  woman
# 3           1       1    0   47      1      0   189         2   First  woman
# 4           0       3    1   47      0      0    43         2   Third    man
# ..        ...     ...  ...  ...    ...    ...   ...       ...     ...    ...
# 886         0       2    1   35      0      0    85         2  Second    man
# 887         1       1    0   24      0      0   153         2   First  woman
# 888         0       3    0   88      1      2   131         2   Third  woman
# 889         1       1    1   34      0      0   153         0   First    man
# 890         0       3    1   42      0      0    30         1   Third    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN            2    no  False
# 1         False    C            0   yes  False
# 2         False  NaN            2   yes   True
# 3         False    C            2   yes  False
# 4          True  NaN            2    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN            2    no   True
# 887       False    B            2   yes   True
# 888       False  NaN            2    no  False
# 889        True    C            0   yes   True
# 890        True  NaN            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['class'] = le.fit_transform(df['class'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked  class    who  \
# 0           0       3    1   28      1      0    18         2      2    man
# 1           1       1    0   51      1      0   207         0      0  woman
# 2           1       3    0   34      0      0    41         2      2  woman
# 3           1       1    0   47      1      0   189         2      0  woman
# 4           0       3    1   47      0      0    43         2      2    man
# ..        ...     ...  ...  ...    ...    ...   ...       ...    ...    ...
# 886         0       2    1   35      0      0    85         2      1    man
# 887         1       1    0   24      0      0   153         2      0  woman
# 888         0       3    0   88      1      2   131         2      2  woman
# 889         1       1    1   34      0      0   153         0      0    man
# 890         0       3    1   42      0      0    30         1      2    man
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN            2    no  False
# 1         False    C            0   yes  False
# 2         False  NaN            2   yes   True
# 3         False    C            2   yes  False
# 4          True  NaN            2    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN            2    no   True
# 887       False    B            2   yes   True
# 888       False  NaN            2    no  False
# 889        True    C            0   yes   True
# 890        True  NaN            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['who'] = le.fit_transform(df['who'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# 0           0       3    1   28      1      0    18         2      2    1
# 1           1       1    0   51      1      0   207         0      0    2
# 2           1       3    0   34      0      0    41         2      2    2
# 3           1       1    0   47      1      0   189         2      0    2
# 4           0       3    1   47      0      0    43         2      2    1
# ..        ...     ...  ...  ...    ...    ...   ...       ...    ...  ...
# 886         0       2    1   35      0      0    85         2      1    1
# 887         1       1    0   24      0      0   153         2      0    2
# 888         0       3    0   88      1      2   131         2      2    2
# 889         1       1    1   34      0      0   153         0      0    1
# 890         0       3    1   42      0      0    30         1      2    1
#
#      adult_male deck  embark_town alive  alone
# 0          True  NaN            2    no  False
# 1         False    C            0   yes  False
# 2         False  NaN            2   yes   True
# 3         False    C            2   yes  False
# 4          True  NaN            2    no   True
# ..          ...  ...          ...   ...    ...
# 886        True  NaN            2    no   True
# 887       False    B            2   yes   True
# 888       False  NaN            2    no  False
# 889        True    C            0   yes   True
# 890        True  NaN            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['adult_male'] = le.fit_transform(df['adult_male'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# 0           0       3    1   28      1      0    18         2      2    1
# 1           1       1    0   51      1      0   207         0      0    2
# 2           1       3    0   34      0      0    41         2      2    2
# 3           1       1    0   47      1      0   189         2      0    2
# 4           0       3    1   47      0      0    43         2      2    1
# ..        ...     ...  ...  ...    ...    ...   ...       ...    ...  ...
# 886         0       2    1   35      0      0    85         2      1    1
# 887         1       1    0   24      0      0   153         2      0    2
# 888         0       3    0   88      1      2   131         2      2    2
# 889         1       1    1   34      0      0   153         0      0    1
# 890         0       3    1   42      0      0    30         1      2    1
#
#      adult_male deck  embark_town alive  alone
# 0             1  NaN            2    no  False
# 1             0    C            0   yes  False
# 2             0  NaN            2   yes   True
# 3             0    C            2   yes  False
# 4             1  NaN            2    no   True
# ..          ...  ...          ...   ...    ...
# 886           1  NaN            2    no   True
# 887           0    B            2   yes   True
# 888           0  NaN            2    no  False
# 889           1    C            0   yes   True
# 890           1  NaN            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['deck'] = le.fit_transform(df['deck'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# 0           0       3    1   28      1      0    18         2      2    1
# 1           1       1    0   51      1      0   207         0      0    2
# 2           1       3    0   34      0      0    41         2      2    2
# 3           1       1    0   47      1      0   189         2      0    2
# 4           0       3    1   47      0      0    43         2      2    1
# ..        ...     ...  ...  ...    ...    ...   ...       ...    ...  ...
# 886         0       2    1   35      0      0    85         2      1    1
# 887         1       1    0   24      0      0   153         2      0    2
# 888         0       3    0   88      1      2   131         2      2    2
# 889         1       1    1   34      0      0   153         0      0    1
# 890         0       3    1   42      0      0    30         1      2    1
#
#      adult_male  deck  embark_town alive  alone
# 0             1     7            2    no  False
# 1             0     2            0   yes  False
# 2             0     7            2   yes   True
# 3             0     2            2   yes  False
# 4             1     7            2    no   True
# ..          ...   ...          ...   ...    ...
# 886           1     7            2    no   True
# 887           0     1            2   yes   True
# 888           0     7            2    no  False
# 889           1     2            0   yes   True
# 890           1     7            1    no   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['alive'] = le.fit_transform(df['alive'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# 0           0       3    1   28      1      0    18         2      2    1
# 1           1       1    0   51      1      0   207         0      0    2
# 2           1       3    0   34      0      0    41         2      2    2
# 3           1       1    0   47      1      0   189         2      0    2
# 4           0       3    1   47      0      0    43         2      2    1
# ..        ...     ...  ...  ...    ...    ...   ...       ...    ...  ...
# 886         0       2    1   35      0      0    85         2      1    1
# 887         1       1    0   24      0      0   153         2      0    2
# 888         0       3    0   88      1      2   131         2      2    2
# 889         1       1    1   34      0      0   153         0      0    1
# 890         0       3    1   42      0      0    30         1      2    1
#
#      adult_male  deck  embark_town  alive  alone
# 0             1     7            2      0  False
# 1             0     2            0      1  False
# 2             0     7            2      1   True
# 3             0     2            2      1  False
# 4             1     7            2      0   True
# ..          ...   ...          ...    ...    ...
# 886           1     7            2      0   True
# 887           0     1            2      1   True
# 888           0     7            2      0  False
# 889           1     2            0      1   True
# 890           1     7            1      0   True
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['alone'] = le.fit_transform(df['alone'])

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# 0           0       3    1   28      1      0    18         2      2    1
# 1           1       1    0   51      1      0   207         0      0    2
# 2           1       3    0   34      0      0    41         2      2    2
# 3           1       1    0   47      1      0   189         2      0    2
# 4           0       3    1   47      0      0    43         2      2    1
# ..        ...     ...  ...  ...    ...    ...   ...       ...    ...  ...
# 886         0       2    1   35      0      0    85         2      1    1
# 887         1       1    0   24      0      0   153         2      0    2
# 888         0       3    0   88      1      2   131         2      2    2
# 889         1       1    1   34      0      0   153         0      0    1
# 890         0       3    1   42      0      0    30         1      2    1
#
#      adult_male  deck  embark_town  alive  alone
# 0             1     7            2      0      0
# 1             0     2            0      1      0
# 2             0     7            2      1      1
# 3             0     2            2      1      0
# 4             1     7            2      0      1
# ..          ...   ...          ...    ...    ...
# 886           1     7            2      0      1
# 887           0     1            2      1      1
# 888           0     7            2      0      0
# 889           1     2            0      1      1
# 890           1     7            1      0      1
#
# [891 rows x 15 columns]

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder()
df['alone'] = oe.fit_transform(df[['alone']])   # note: needs 2D input

# %%
df
# Out:
#      survived  pclass  sex  age  sibsp  parch  fare  embarked  class  who  \
# 0           0       3    1   28      1      0    18         2      2    1
# 1           1       1    0   51      1      0   207         0      0    2
# 2           1       3    0   34      0      0    41         2      2    2
# 3           1       1    0   47      1      0   189         2      0    2
# 4           0       3    1   47      0      0    43         2      2    1
# ..        ...     ...  ...  ...    ...    ...   ...       ...    ...  ...
# 886         0       2    1   35      0      0    85         2      1    1
# 887         1       1    0   24      0      0   153         2      0    2
# 888         0       3    0   88      1      2   131         2      2    2
# 889         1       1    1   34      0      0   153         0      0    1
# 890         0       3    1   42      0      0    30         1      2    1
#
#      adult_male  deck  embark_town  alive  alone
# 0             1     7            2      0    0.0
# 1             0     2            0      1    0.0
# 2             0     7            2      1    1.0
# 3             0     2            2      1    0.0
# 4             1     7            2      0    1.0
# ..          ...   ...          ...    ...    ...
# 886           1     7            2      0    1.0
# 887           0     1            2      1    1.0
# 888           0     7            2      0    0.0
# 889           1     2            0      1    1.0
# 890           1     7            1      0    1.0
#
# [891 rows x 15 columns]
