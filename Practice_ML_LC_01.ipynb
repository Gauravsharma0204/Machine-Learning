# %%
import pandas as pd
import matplotlib.pyplot as pl

df = pd.read_csv(r'C:\Users\kumar\Downloads\placement.csv')

x = df[['cgpa']]
y = df['package']

# %%
from sklearn.linear_model import LinearRegression
lg = LinearRegression()
lg.fit(x, y) # Data Trained Karna 
pl.scatter(x,y)

# %%
# lg.predict([[5]])
lg.predict([[5]])
# Out:
# G:\Anaconda\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.86227853])

# %%
pl.plot(x,lg.predict(x))
pl.scatter(x,y)

# %%
print(lg.coef_)
print(lg.intercept_)
x = 1
# Out:
# [0.56959129]
# -0.9856779462557332

# %%
# y = mX + c
y = 0.56959129*45 + --0.9856779462557332
y
# Out:
# 26.61728599625573
